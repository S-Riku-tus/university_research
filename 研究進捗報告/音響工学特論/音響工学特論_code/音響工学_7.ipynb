# %%
import numpy as np

# シグモイド関数の定義
def sigmoid(x):
    return 1 / (1 + np.exp(-x))

old_W_1 = [2.0, 3.0]  # 古いWjkの中で、第1ノードに伝搬する重み
O_j = [0.4, 0.5]  # 各ノードの出力
a = 0.1  # 学習率
e_1 = 0.8  # 誤差逆伝搬後の再構成されたノード1の誤差
W_jk_1 = -(e_1) * sigmoid(np.dot(old_W_1, O_j)) * (1 - sigmoid(np.dot(old_W_jk, O_j))) * 0.4

new_W_jk_1 = old_W_1[0] - a * W_jk_1

print(new_W_jk_1)
# Out:
# 2.002650226143704

# %%
e_2 = 0.5  # 誤差逆伝搬後の再構成されたノード2の誤差
old_W_2 = [1.0, 4.0]  # 古いWjkの中で、第2ノードに伝搬する重み

W_jk_2 = -(e_2) * sigmoid(np.dot(old_W_2, O_j)) * (1 - sigmoid(np.dot(old_W_2, O_j))) * 0.4

new_W_jk_2 = old_W_2[1] - a * W_jk_2

print(new_W_jk_2)
# Out:
# 4.001525099981037
